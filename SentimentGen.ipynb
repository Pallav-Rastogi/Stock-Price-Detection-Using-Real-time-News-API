# %%
import yfinance as yf
from newsapi import NewsApiClient
import pandas as pd
import numpy as np
from datetime import datetime, timezone
import pytz
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import torch
# Out:
# c:\Users\prast\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(

# %%
# Init
newsapi = NewsApiClient(api_key='2308235029104f24b8b883942519253a')
newsdata = newsapi.get_everything(q='microsoft',
                                    #   sources='bbc-news,the-verge',
                                    #   domains='bbc.co.uk,techcrunch.com',
                                      from_param='2025-06-04',
                                      to='2025-07-04',
                                      language='en',
                                    #   sort_by='relevancy',
                                    )

# %%
newsdata
# Out:
# {'status': 'ok',
#  'totalResults': 9481,
#  'articles': [{'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Kylie Robison',
#    'title': 'OpenAI’s Unreleased AGI Paper Could Complicate Microsoft Negotiations',
#    'description': 'The partnership between OpenAI and Microsoft in many ways hinges on the definition of artificial general intelligence, creating a tension that has spilled over into OpenAI research that has not been made public.',
#    'url': 'https://www.wired.com/story/openai-five-levels-agi-paper-microsoft-negotiations/',
#    'urlToImage': 'https://media.wired.com/photos/6837480c7f38ebcc93957426/191:100/w_1280,c_limit/AI-Labs-Promote-Bottom-Line-Business-2213399161.jpg',
#    'publishedAt': '2025-06-27T19:35:29Z',
#    'content': 'A small clause inside OpenAIs contract with Microsoft, once considered a distant hypothetical, has now become a flashpoint in one of the biggest partnerships in tech.\r\nThe clause states that if OpenA… [+3289 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'This is how Microsoft is combining Windows and Xbox for handheld PCs',
#    'description': 'Microsoft and Asus have just announced two ROG Xbox Ally devices that include a new full-screen Xbox experience for handhelds. After promising to combine “the best of Xbox and Windows together” for handhelds earlier this year, Microsoft is now revealing exact…',
#    'url': 'https://www.theverge.com/news/682011/microsoft-windows-xbox-pc-combination-features-rog-xbox-ally-devices',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/BOOTUP.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#    'publishedAt': '2025-06-08T17:18:15Z',
#    'content': 'Two new Xbox Ally devices introduce Microsofts much-needed improvements to handheld gaming PCs.\r\nTwo new Xbox Ally devices introduce Microsofts much-needed improvements to handheld gaming PCs.\r\nMicro… [+6517 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Microsoft’s next-gen\xa0Xbox\xa0has an AMD chip inside and is ‘not locked to a single store’',
#    'description': 'Microsoft is confirming today that it’s working on a next-gen Xbox console in partnership with AMD. Xbox president Sarah Bond made the announcement in a minute-long video posted to YouTube, promising to deliver “an Xbox experience not locked to a single store…',
#    'url': 'https://www.theverge.com/news/688407/microsoft-next-gen-xbox-cloud-amd',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/25832862/STK048_XBOX_2_A.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-06-17T17:33:32Z',
#    'content': 'The next generation of Xbox devices is all about playing games anywhere.\r\nThe next generation of Xbox devices is all about playing games anywhere.\r\nMicrosoft is confirming today that its working on a… [+3425 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Microsoft is laying off as many as 9,000 employees',
#    'description': 'Microsoft confirmed that it’s laying off as many as 9,100 employees, or about four percent of its workforce, in yet another round of cuts this year, reports the Seattle Times. Employees in Microsoft’s Xbox division, known as Microsoft Gaming, are being hit ha…',
#    'url': 'https://www.theverge.com/news/693535/microsoft-layoffs-july-2025-xbox',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/25832915/STK095_MICROSOFT_2_CVirginia_D.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-07-02T13:21:37Z',
#    'content': 'Microsofts latest job cuts come after multiple rounds of layoffs over the past year.\r\nMicrosoft confirmed that its laying off as many as 9,100 employees, or about four percent of its workforce, in ye… [+3529 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Microsoft should change its Copilot advertising, says watchdog',
#    'description': 'Microsoft’s Copilot advertising has been criticized by an industry watchdog for its productivity claims and confusing use of Copilot branding. The Better Business Bureau’s National Advertising Division (NAD) has reviewed Microsoft’s Copilot advertising, and r…',
#    'url': 'https://www.theverge.com/news/688056/microsoft-copilot-advertising-watchdog-response',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/02/STK259_MICROSOFT_COPILOT_3__D.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-06-17T11:26:56Z',
#    'content': 'An advertising watchdog has recommended that Microsoft discontinue or modify some of its Copilot claims.\r\nMicrosofts Copilot advertising has been criticized by an industry watchdog for its productivi… [+2394 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Inside Microsoft’s complicated relationship with OpenAI',
#    'description': "Beyond the selfies between Microsoft CEO Satya Nadella and OpenAI CEO Sam Altman, and the friendly conversations between the pair on stage, all is not well with Microsoft's $13 billion AI investment. Over the past year, multiple reports have painted a picture…",
#    'url': 'https://www.theverge.com/notepad-microsoft-newsletter/688964/microsoft-openai-relationship-notepad',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/gettyimages-1778706496.jpg?quality=90&strip=all&crop=0%2C10.843709023462%2C100%2C78.312581953077&w=1200',
#    'publishedAt': '2025-06-18T15:11:54Z',
#    'content': 'The cracks are showing in this unique tech partnership.\r\nBeyond the selfies between Microsoft CEO Satya Nadella and OpenAI CEO Sam Altman, and the friendly conversations between the pair on stage, al… [+12433 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren, Jay Peters',
#    'title': 'Microsoft cancels its Perfect Dark and Everwild Xbox games',
#    'description': 'Microsoft is canceling its Perfect Dark and Everwild games as part of sweeping cuts to its Xbox division. Xbox Game Studios chief Matt Booty revealed that Microsoft will be closing The Initiative, the studio behind Perfect Dark, in an internal memo to Xbox em…',
#    'url': 'https://www.theverge.com/news/696877/xbox-perfect-dark-everwild-cancelled-the-initiative-layoffs',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/07/32da1e43-2101-4d77-a8c2-1906f7525fb0.jpg?quality=90&strip=all&crop=0%2C3.4383212962771%2C100%2C93.123357407446&w=1200',
#    'publishedAt': '2025-07-02T17:18:38Z',
#    'content': 'The company is closing The Initiative, too.\r\nMicrosoft is canceling its Perfect Dark and Everwild games as part of sweeping cuts to its Xbox division. Xbox Game Studios chief Matt Booty revealed that… [+1683 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters, Tom Warren',
#    'title': 'Phil Spencer isn’t retiring as the chief of Xbox ‘anytime soon’',
#    'description': 'Microsoft says that Phil Spencer, Microsoft Gaming CEO and the head of Xbox, isn’t retiring “anytime soon.” The company has responded to rumors of Spencer’s retirement, which have spread online today following Microsoft’s major layoffs. “Phil is not retiring …',
#    'url': 'https://www.theverge.com/news/696922/phil-spencer-xbox-microsoft-gaming-retiring',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/07/VRG_Illo_STK184_L_Normand_PhilSpencer_Neutral.jpg.webp?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-07-02T19:40:27Z',
#    'content': 'Spencer has headed up Microsofts Xbox efforts since 2014.\r\nMicrosoft says that Phil Spencer, Microsoft Gaming CEO and the head of Xbox, isnt retiring anytime soon. The company has responded to rumors… [+1504 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Xbox console games are suddenly showing up inside the Xbox PC app',
#    'description': 'Something strange is going on with Microsoft’s Xbox app on Windows. Over the past few days, the Xbox PC app has started showing Xbox console games inside the library. While you can’t install games like the original Alan Wake for Xbox 360, it shows up if you o…',
#    'url': 'https://www.theverge.com/news/682235/xbox-pc-games-console-library-xbox-360',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/xboxpcapp.jpg?quality=90&strip=all&crop=0%2C8.1151832460733%2C100%2C83.769633507853&w=1200',
#    'publishedAt': '2025-06-08T09:08:58Z',
#    'content': 'Were starting to see some early signs of Microsoft bringing Xbox and Windows closer together.\r\nWere starting to see some early signs of Microsoft bringing Xbox and Windows closer together.\r\nSomething… [+2279 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Microsoft just teased its next-gen Xbox console, and nobody noticed',
#    'description': "I feel like a broken record, but I've been writing for more than a year that the next Xbox console will be more PC-like. Now, I think Microsoft just teased its next-gen Xbox plans while announcing its partnership with Asus to bring two Xbox Ally handhelds to …",
#    'url': 'https://www.theverge.com/notepad-microsoft-newsletter/686101/microsoft-xbox-next-gen-console-handheld-hints-notepad',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/chrome_nF7vRuPMAv.jpg?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#    'publishedAt': '2025-06-12T16:06:56Z',
#    'content': 'Microsofts Xbox handheld work is an early look at the next Xbox consoles.\r\nI feel like a broken record, but Ive been writing for more than a year that the next Xbox console will be more PC-like. Now,… [+12627 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Microsoft\xa0Edge is getting an AI-powered browser history that works with typos',
#    'description': 'Microsoft has started testing a new feature for its Edge browser that adds an AI-powered search to browsing history. This new “enhanced search” feature lets you find websites in your browser history even if you use a phrase, synonym, or even a typo that’s sim…',
#    'url': 'https://www.theverge.com/news/684195/microsoft-edge-ai-browser-history-search-feature',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/24385268/STK148_Microsoft_Edge_1.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-06-10T12:54:37Z',
#    'content': 'You can test this new enhanced search feature in beta versions of Edge.\r\nMicrosoft has started testing a new feature for its Edge browser that adds an AI-powered search to browsing history. This new … [+1267 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Lucas Ropek',
#    'title': 'OpenAI and Microsoft Execs Reportedly Considering the ‘Nuclear Option’',
#    'description': "There's trouble in AI paradise.",
#    'url': 'https://gizmodo.com/openai-and-microsofts-rocky-partnership-reportedly-has-execs-considering-the-nuclear-option-2000616643',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/01/15767ad3477a80fccec9a869f907d5bd.jpg',
#    'publishedAt': '2025-06-17T12:40:38Z',
#    'content': 'OpenAI and Microsoft like to present themselves as the power couple of Silicon Valley, but behind closed doors, it’s looking increasingly like a distraught and loveless marriage. The two companies, w… [+3056 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Luc Olinga',
#    'title': 'Microsoft Just Fired About 9,000 People While Making Billions',
#    'description': 'The tech giant is posting staggering profits and leading the AI revolution.',
#    'url': 'https://gizmodo.com/microsoft-just-fired-about-9000-people-while-making-billions-2000623667',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2023/05/cb79fa87c30c913a9fbbf251632de056.jpg',
#    'publishedAt': '2025-07-03T00:54:49Z',
#    'content': 'Microsoft is laying off thousands of employees, even as its profits and stock price hit historic highs. For many worried about the future of work in the age of artificial intelligence, the message is… [+3915 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Microsoft and Asus announce two Xbox Ally handhelds with new Xbox full-screen experience',
#    'description': 'Microsoft and Asus have been working together over the past year to create not one, but two new ROG Xbox Ally handhelds. Both of these Xbox Ally devices, part of the Project Kennan effort I reported on earlier this year, include a new full-screen Xbox experie…',
#    'url': 'https://www.theverge.com/news/682009/microsoft-asus-rog-xbox-ally-devices-new-windows-xbox-experience',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/DUAL_16X9.png?quality=90&strip=all&crop=0%2C3.5043662306087%2C100%2C92.991267538783&w=1200',
#    'publishedAt': '2025-06-08T17:12:20Z',
#    'content': 'Project Kennan arrives alongside a new fullscreen Xbox experience that hides the complexities of Windows away.\r\nProject Kennan arrives alongside a new fullscreen Xbox experience that hides the comple… [+6079 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Microsoft adds Steam games to its Xbox PC app on Windows',
#    'description': 'Microsoft is starting to test its new aggregated gaming library in its Xbox PC app on Windows. Xbox Insiders will now be able to see their Steam and Battle.net games all within the Xbox app — making it a single launcher for most installed PC games. This new c…',
#    'url': 'https://www.theverge.com/news/690967/microsoft-xbox-app-windows-steam-games-aggregated-library-support-beta',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/Finalv2-2505-June-WIRE-AggLib-9a0725ea199fe16f8c9c.png?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#    'publishedAt': '2025-06-23T15:03:07Z',
#    'content': 'Xbox Insiders get access to Microsofts new aggregated gaming library today.\r\nMicrosoft is starting to test its new aggregated gaming library in its Xbox PC app on Windows. Xbox Insiders will now be a… [+1091 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'A week in\xa0Xbox\xa0VR with\xa0Microsoft\xa0and Meta’s new $399 headset',
#    'description': "Microsoft and Meta announced an Xbox-branded Quest VR headset last year, and it's going on sale today for $399.99. The Meta Quest 3S Xbox Edition is a custom colorway VR headset that comes bundled with an Xbox wireless controller, matching Touch Plus controll…",
#    'url': 'https://www.theverge.com/hands-on/690978/meta-quest-3s-xbox-edition-vr-headset-release-date-pricing',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/xboxmetaquest3s_twarren_01.jpg?quality=90&strip=all&crop=0%2C10.486021930258%2C100%2C79.027956139484&w=1200',
#    'publishedAt': '2025-06-24T13:02:05Z',
#    'content': 'The Quest 3S Xbox Edition is a custom colorway VR headset bundled with an Xbox controller.\r\nMicrosoft and Meta announced an Xbox-branded Quest VR headset last year, and its going on sale today for $3… [+2789 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Microsoft’s new Copilot Vision can ‘see’ your apps on Windows',
#    'description': 'Microsoft is launching Copilot Vision for Windows today, an extension of its AI assistant that lets you share your screen or apps so that Copilot can do things like coach you through using Adobe Photoshop features or analyze the photos and webpages you’re loo…',
#    'url': 'https://www.theverge.com/news/685963/microsoft-copilot-vision-windows-launch',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/Copilot-Vision-on-Windows.png?quality=90&strip=all&crop=0%2C3.5043662306087%2C100%2C92.991267538783&w=1200',
#    'publishedAt': '2025-06-12T16:03:42Z',
#    'content': 'Copilot Vision on Windows is now available to all Copilot Pro subscribers in the US.\r\nMicrosoft is launching Copilot Vision for Windows today, an extension of its AI assistant that lets you share you… [+1548 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew Liszewski',
#    'title': 'The Xbox 360 dashboard just got updated… to advertise newer Xboxes',
#    'description': 'Earlier this week some devoted Xbox 360 users booted up their aging consoles to find that Microsoft had updated the home screen to finally resolve an issue with box art. But in addition to that fix, several users on Reddit, as well as Kotaku, have confirmed t…',
#    'url': 'https://www.theverge.com/news/693631/microsoft-xbox-360-dashboard-software-update-ads',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/xbox360.jpg?quality=90&strip=all&crop=0,10.732984293194,100,78.534031413613',
#    'publishedAt': '2025-06-26T18:40:34Z',
#    'content': 'Microsoft is still updating the Xbox 360, nearly 20 years later.\r\n\n\nEarlier this week some devoted Xbox 360 users booted up their aging consoles to find that Microsoft had updated the home screen to … [+1707 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Windows 11’s indicators for volume and brightness can soon be moved out of the way',
#    'description': 'Microsoft is testing a new feature in Windows 11 that will let you move hardware indicators pop-ups like volume and screen brightness to the top-left and top-center positions of a display. The customization feature is part of a new Dev Channel build of Window…',
#    'url': 'https://www.theverge.com/news/691779/microsoft-windows-11-hardware-indicators-customization',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/indicator-top-left.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-06-24T09:16:58Z',
#    'content': 'The hardware indicator pop-ups can now appear in the top-left of a screen.\r\n\n\nMicrosoft is testing a new feature in Windows 11 that will let you move hardware indicators pop-ups like volume and scree… [+1397 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'David Pierce',
#    'title': 'Switch, Xbox, and the portable future of games',
#    'description': "The Switch 2 is a hit (and a supply chain success story). Microsoft is starting to show off its plan for the future of Xbox. And everywhere you look, there are reasons to think we're headed toward a very different kind of gaming device. Maybe it'll be even mo…",
#    'url': 'https://www.theverge.com/the-vergecast/686637/switch-2-xbox-ally-portable-gaming-vergecast',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/VST_0613_Site.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-06-13T13:28:22Z',
#    'content': 'On The Vergecast: handheld consoles, WWDC vibes, and Google Zero.\r\nOn The Vergecast: handheld consoles, WWDC vibes, and Google Zero.\r\nThe Switch 2 is a hit (and a supply chain success story). Microso… [+1537 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Tiffany Connors',
#    'title': 'If OpenAI and Microsoft Break Up, What Does It Mean for Copilot? Try These AI Alternatives',
#    'description': 'OpenAI and Microsoft are reportedly calling it quits, but disentangling AI integration from Microsoft programs could prove tricky.',
#    'url': 'https://www.cnet.com/tech/services-and-software/if-openai-and-microsoft-break-up-what-does-it-mean-for-copilot-try-these-ai-alternatives/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/f6ac0cb9161a261bab14092cc54862e822790e6a/hub/2025/06/03/fbc815a7-8cc6-404c-848d-1f97bfadb9cf/copilot.jpg?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2025-06-17T13:36:00Z',
#    'content': 'The love-hate relationship between\xa0OpenAI and Microsoft may be heading toward a permanent dissolution, according to a new report by the\xa0Wall Street Journal. That raises questions about the future of … [+1659 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Joe Tilleli',
#    'title': '5-Star HP Laptop Is Nearly 70% Off, Practically Free With Windows 11 Pro, MS Office, and More',
#    'description': 'Save almost 70% on the HP laptop for students and businesses along with some neat gifts over at Amazon.',
#    'url': 'https://gizmodo.com/5-star-hp-laptop-is-nearly-70-off-practically-free-with-windows-11-pro-ms-office-and-more-2000612656',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/HPStudentBusinessLaptop-1200x675.jpg',
#    'publishedAt': '2025-06-10T16:40:37Z',
#    'content': 'Schools is out but the next semester will be here before you know it. Is you college student equipped to take on all their classes? Make sure they are kitted with the right laptop to get all their cl… [+1887 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Barr',
#    'title': 'The Xbox Handheld Is Launching at the Worst Possible Moment',
#    'description': 'The ROG Xbox Ally is stuck between a rock and a hard place: the Switch 2 and Steam Deck.',
#    'url': 'https://gizmodo.com/the-xbox-handheld-is-launching-at-the-worst-possible-moment-2000613111',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Xbox-Ally-ROG-Handheld-HEro-1200x675.jpg',
#    'publishedAt': '2025-06-09T14:48:57Z',
#    'content': 'Who has two thumbs and wants to reestablish Windows as the main way to play games on handhelds? Its Microsoft, which finally revealed its ROG Xbox Ally with its forking appendage grips in concert wit… [+5861 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Gizmodo Deals',
#    'title': 'Amazon Cuts Its Entire Margin on This HP 15.6″ Laptop, Now 73% Off to a New Record Low',
#    'description': 'This HP 15" laptop is so cheap that it completely crushes the competition.',
#    'url': 'https://gizmodo.com/amazon-cuts-its-entire-margin-on-this-hp-15-6-laptop-now-73-off-to-a-new-record-low-2000614259',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/hp-15-touchscreen-laptop-1200x675.jpg',
#    'publishedAt': '2025-06-11T11:40:12Z',
#    'content': 'If you’re looking for around for a laptop that delivers amazing value, there’s an HP 15.6″ touchscreen laptop currently on sale at Amazon that’s hard to resist: It is now available at a staggering pr… [+2278 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Joe Tilleli',
#    'title': 'Dell Offers Its 4.8 Rated 15.6″ Laptop for Almost 60% to Clear Out Stock, Loaded With Windows 11 Pro',
#    'description': "Dell has it's 3530 laptop designed for home, business, and student use is now almost $800 off on Amazon.",
#    'url': 'https://gizmodo.com/dell-offers-its-4-8-rated-15-6-laptop-for-almost-60-to-clear-out-stock-loaded-with-windows-11-pro-2000611467',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Dell-15.622-3530-Laptop--1200x675.jpg',
#    'publishedAt': '2025-06-05T12:10:38Z',
#    'content': 'When was the last time you upgraded your laptop? If youre still working off of a piece of ten year old tech, it may be time to start looking for a replacement. This Dell laptop is a super versatile o… [+2122 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Gizmodo Deals',
#    'title': 'This HP Laptop with Windows 11 and Office 365 Is Only $179, Lowest Price Ever for an HP Laptop',
#    'description': 'At this price, it’s a no-brainer.',
#    'url': 'https://gizmodo.com/this-hp-laptop-with-windows-11-and-office-365-is-only-179-lowest-price-ever-for-an-hp-laptop-2000621850',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/05/hp-14-laptop-celeron-1200x675.jpg',
#    'publishedAt': '2025-06-29T13:40:35Z',
#    'content': 'If youre looking for a reliable computer without spending $1,000 or $2,000, HP is always a solid choice thanks to its wide range of dependable products. Right now, though, Amazon is offering a deal t… [+2149 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'James Pero',
#    'title': 'Xbox Needs to Get Weirder or Die Trying',
#    'description': '"I think Xbox hardware is dead," said Laura Fryer, a founding member of Xbox, in a video slamming Microsoft\'s fumbling of the game system.',
#    'url': 'https://gizmodo.com/xbox-needs-to-get-weirder-or-die-trying-2000622054',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/xboxseriess-1200x675.jpg',
#    'publishedAt': '2025-06-30T15:56:01Z',
#    'content': 'Xbox is in a weird place right now, and I’m not the only one who thinks so. In fact, people with more important opinions on the subject than myself seem to agree: if Microsoft doesn’t get its shit to… [+5647 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Oscar Gonzalez',
#    'title': 'Microsoft surprises fans with reveal of ROG Xbox Ally handheld',
#    'description': 'The Xbox is about to get portable.',
#    'url': 'https://www.cnet.com/tech/gaming/microsoft-surprises-fans-with-reveal-of-rog-xbox-ally-handheld/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/464d7aa4859db1599ef88a66cd565ed47c4b4c90/hub/2025/06/08/442f2953-ca67-4d74-bd68-63d2c69c1869/2025-06-08-10-05-10-00-02-40-42-still001.jpg?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2025-06-08T17:18:32Z',
#    'content': 'During the Xbox Games Showcase, Microsoft finally revealed its handheld in a partnership with Asus. The ROG Xbox Ally will come later this year and will be available in two variants.\r\nThe new portabl… [+1134 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Macy Meyer',
#    'title': 'Microsoft Accidentally Replaces Windows 11 Startup Sound with Vista Chime',
#    'description': 'Time warp back to 2007! Microsoft\'s accidental yet "delightful blast from the past" sparks nostalgia online.',
#    'url': 'https://www.cnet.com/tech/services-and-software/microsoft-accidentally-replaces-windows-11-startup-sound-with-vista-chime/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/bc1d963cb2f9994f134e95c027f65a7f47e40197/hub/2017/04/11/9c38efd3-fae0-42b6-8be8-56d8eb1eaddc/windowsvista.jpg?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2025-06-16T18:26:24Z',
#    'content': "Microsoft briefly transported users back to 2007 this week when the company mistakenly swapped Windows 11's familiar startup chime with the iconic Windows Vista boot sound.\r\nThe mix-up appeared in a … [+879 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'cmlee@insider.com (Lee Chong Ming)',
#    'title': "Microsoft turned me down twice. Here's what I did differently the third time to get the job.",
#    'description': 'Twice rejected by Microsoft, a software engineer turned setbacks into the ultimate motivator and aced his third try.',
#    'url': 'https://www.businessinsider.com/rejected-twice-microsoft-software-engineer-plan-interview-tips-2025-6',
#    'urlToImage': 'https://i.insider.com/683ff203c19ab3675c109943?width=1200&format=jpeg',
#    'publishedAt': '2025-06-19T00:00:02Z',
#    'content': 'This as-told-to essay is based on a conversation with Adit Sheth, a senior software engineer at Microsoft. Business Insider has verified his employment.This interview has been edited for length and c… [+2787 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'katherineli@insider.com (Katherine Li)',
#    'title': "Nvidia dethrones Microsoft as the world's most valuable publicly traded company with a $3.45 trillion market cap",
#    'description': 'Nvidia reclaims top spot as the most valuable publicly traded company with a $3.45 trillion market cap, surpassing Microsoft.',
#    'url': 'https://www.businessinsider.com/nvidia-dethrones-microsoft-as-the-worlds-most-valuable-company-2025-6',
#    'urlToImage': 'https://i.insider.com/683f8f8c9b2a601d01b240c5?width=1200&format=jpeg',
#    'publishedAt': '2025-06-04T02:09:51Z',
#    'content': 'Nvidia reclaimed the title of the most valuable publicly traded company.\r\nThe AI chipmaking giant led by CEO Jensen Huang surpassed Microsoft after its stock jumped 3% to close at $141.40 on Tuesday.… [+1771 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Ashley Stewart',
#    'title': 'Leaked Microsoft org chart shows the team Jay Parikh assembled to lead CoreAI, full of fellow ex-Meta execs',
#    'description': "Parikh's team includes some of his former Meta colleagues, plus longtime Microsoft executives.",
#    'url': 'https://www.businessinsider.com/leaked-microsoft-org-chart-shows-execs-running-new-ai-group-2025-6',
#    'urlToImage': 'https://i.insider.com/6842072e9d73a0031e8dfdfe?width=1200&format=jpeg',
#    'publishedAt': '2025-06-06T09:00:01Z',
#    'content': "Microsoft\r\n<ul><li>Jay Parikh leads Microsoft's new CoreAI group, created in January.</li><li>The team includes Parikh's former Meta colleagues, plus longtime Microsoft executives.</li><li>CoreAI is … [+3328 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Jason Coles',
#    'title': 'HP 15.6″ Touchscreen Laptop (64GB RAM, 2TB SSD) Is Nearly $2,000 Off, Lowest Price for This New Model',
#    'description': 'Who needs a MacBook when this powerhouse is nearly 70% off?',
#    'url': 'https://gizmodo.com/hp-15-6-touchscreen-laptop-64gb-ram-2tb-ssd-is-nearly-2000-off-lowest-price-for-this-new-model-2000622720',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/07/laptop-deal-1200x675.jpg',
#    'publishedAt': '2025-07-02T11:40:02Z',
#    'content': 'Being able to use your laptop however you want is a must for a lot of us. Whether you’re working from home, on a train, or just studying, a good laptop is a huge deal. There are loads of great option… [+1927 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Joe Tilleli',
#    'title': 'LG Gram 17 Touchscreen Laptop Copilot+ PC Is $3,000 Off, This 5-Star 2025 Model at 60% Off Is Going Fast',
#    'description': 'Save 60% on the LG Gram 17 touchscreen laptop for a limited time at Amazon.',
#    'url': 'https://gizmodo.com/lg-gram-17-touchscreen-laptop-copilot-pc-is-3000-off-this-5-star-2025-model-at-60-off-is-going-fast-2000622898',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/07/LGGram17-1200x675.jpg',
#    'publishedAt': '2025-07-02T15:10:45Z',
#    'content': 'When was the last time you upgraded your laptop? If youre still working off of a piece of ten year old tech, it may be time to start looking for a replacement. The Dell Inspiron 16 laptop is a super … [+2245 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Gizmodo Deals',
#    'title': '$2,000 Slashed Off Dell’s 15-Inch Laptop, Prime Day Deal Leaves Amazon’s Margin Gone',
#    'description': 'With specs this powerful, it almost feels suspicious to find this laptop at such a price on Amazon.',
#    'url': 'https://gizmodo.com/2000-slashed-off-dells-15-inch-laptop-prime-day-deal-leaves-amazons-margin-gone-2000620047',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/dell-inspiron-touchscreen-1200x675.jpg',
#    'publishedAt': '2025-06-25T11:10:13Z',
#    'content': 'If you’re looking for a premium laptop, this early Prime Day deal on the Dell Inspiron 15-inch touchscreen laptop is one you won’t want to miss – and it’s open to both Prime and non-Prime members.\r\nA… [+2055 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Gizmodo Deals',
#    'title': 'This 15″ 1TB HP Laptop is Almost Free, Amazon Offers 76% Off in Early Prime Day Deal',
#    'description': 'Amazon is offering $1500 off on one of the most popular laptops in 2025.',
#    'url': 'https://gizmodo.com/this-15-1tb-hp-laptop-is-almost-free-amazon-offers-76-off-in-early-prime-day-deal-2000619165',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/hp-laptop-15-1tb-1200x675.jpg',
#    'publishedAt': '2025-06-23T19:47:54Z',
#    'content': 'HP typically retails their laptops between $1,000 to $3,000, unless you are able to snag an unbelievable sale such as the one Amazon is currently running ahead of Prime Day. You can get a 2025 HP (1T… [+1981 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Barr',
#    'title': 'Meta’s Quest 3S Xbox Edition Is a Great Value, but There’s Just One Big Tradeoff',
#    'description': "It's also the only way to get a black Quest headset.",
#    'url': 'https://gizmodo.com/metas-quest-3s-xbox-edition-is-a-great-value-but-theres-just-one-big-tradeoff-2000618336',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Meta-Quest-3S-XBOX-2-1200x675.jpg',
#    'publishedAt': '2025-06-24T13:00:23Z',
#    'content': 'Microsoft wants everything to be an Xbox, but the problem with its ongoing ambition to rebrand every gaming-capable device as a pseudo gaming console is so few devices look like an Xbox. The next ste… [+5968 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'Starbucks To Roll Out Microsoft Azure OpenAI Assistant For Baristas',
#    'description': 'Starbucks is piloting a generative AI assistant called "Green Dot Assist" to streamline barista tasks and improve service speed, with plans for a broader rollout in fiscal 2026. The assistant is built on Microsoft Azure\'s OpenAI platform. CNBC reports: Instea…',
#    'url': 'https://slashdot.org/story/25/06/10/2032225/starbucks-to-roll-out-microsoft-azure-openai-assistant-for-baristas',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/ai_64.png',
#    'publishedAt': '2025-06-10T22:20:00Z',
#    'content': "Instead of flipping through manuals or accessing Starbucks' intranet, baristas will be able to use a tablet behind the counter equipped with Green Dot Assist to get answers to a range of questions, f… [+756 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Microsoft Is Deleting Old Drivers From Windows Update',
#    'description': 'BrianFagioli writes: In a move that could quietly wreak havoc across the Windows ecosystem, Microsoft is purging outdated drivers from Windows Update. The company claims it is doing this for security and reliability, but the result might be broken hardware fo…',
#    'url': 'https://tech.slashdot.org/story/25/06/20/1539228/microsoft-is-deleting-old-drivers-from-windows-update',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/microsoft_64100.png',
#    'publishedAt': '2025-06-20T16:01:00Z',
#    'content': 'In a move that could quietly wreak havoc across the Windows ecosystem, Microsoft is purging outdated drivers from Windows Update. The company claims it is doing this for security and reliability, but… [+506 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'Microsoft 365 Brings the Shutters Down On Legacy Protocols',
#    'description': 'Starting mid-July 2025, Microsoft 365 will begin blocking legacy authentication protocols like Remote PowerShell and FrontPage RPC to enhance security under its "Secure by Default" initiative. Admins must now grant explicit consent for third-party app access,…',
#    'url': 'https://it.slashdot.org/story/25/06/19/2046206/microsoft-365-brings-the-shutters-down-on-legacy-protocols',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/security_64.png',
#    'publishedAt': '2025-06-19T21:50:00Z',
#    'content': 'First in line for the chop is legacy browser authentication to SharePoint and OneDrive using the Remote PowerShell (RPS) protocol. According to Microsoft, legacy authentication protocols like RPS "ar… [+886 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': "Lyon Abandons Microsoft Office To Strengthen 'Digital Sovereignty'",
#    'description': 'The City of Lyon will replace Microsoft\'s office suite with free office software, including OnlyOffice for office work and Linux and PostgreSQL for systems and databases. The city aims to "no longer be dependent on American software solutions and acquire true…',
#    'url': 'https://slashdot.org/story/25/06/25/1757229/lyon-abandons-microsoft-office-to-strengthen-digital-sovereignty',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/microsoft_64100.png',
#    'publishedAt': '2025-06-25T18:50:00Z',
#    'content': 'Lyon is 3rd largest city in France, population 520,774 (2022).\r\n"Behind OnlyOffice hides the Company Ascensio System SIA, which have their Headquaters in Riga (Latvia) and London (Great Britain). The… [+216 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Shubhangi Goel',
#    'title': 'Late-night work logins are on the rise, Microsoft finds',
#    'description': "To keep up with late calls and emails, more employees are punching back in after hours, Microsoft's survey found.",
#    'url': 'https://www.businessinsider.com/late-night-work-logins-email-meetings-after-hours-microsoft-survey-2025-6',
#    'urlToImage': 'https://i.insider.com/68524bbef748d8c055f3e775?width=1200&format=jpeg',
#    'publishedAt': '2025-06-18T06:33:06Z',
#    'content': 'Rising expectations are blurring work-life boundaries, leading to longer working hours.Luis Alvarez/Getty Images\r\n<ul><li>Microsoft data shows that employees are working late, with meetings after 8 p… [+2827 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Zachary McAuliffe',
#    'title': 'Xbox Is Bringing These Call of Duty and Warcraft Games to Game Pass in June',
#    'description': "While Microsoft is adding those games to Xbox Game Pass, it's also removing a handful of others from the service on June 30.",
#    'url': 'https://www.cnet.com/tech/services-and-software/xbox-is-bringing-these-call-of-duty-and-warcraft-games-to-game-pass-in-june/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/cb70022caa91043a4f4e1b84bc852045db8b4711/hub/2025/06/17/41d0706a-4077-47f8-92f6-deacb3656189/screenshot-2025-06-17-at-1-05-16pm.png?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2025-06-17T18:00:28Z',
#    'content': 'The Call of Duty franchise got its start as a first-person shooter set during World War Two. On June 30, Game Pass subscribers will be able to return to that war and take part in historical battles i… [+6532 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Emma Roth',
#    'title': 'Facebook rolls out passkey support to fight phishing attacks',
#    'description': 'Facebook is adding support for passkeys on its mobile app. That means you’ll be able to log into the platform using your device’s authentication method, like your fingerprint, face scan, or PIN, making it more difficult for bad actors to take control of your …',
#    'url': 'https://www.theverge.com/news/689410/facebook-passkey-support-phishing-attacks',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/STK442_Password_Manager_A_CVirginia.jpg?quality=90&strip=all&crop=0%2C9.9676601489831%2C100%2C80.064679702034&w=1200',
#    'publishedAt': '2025-06-18T17:14:22Z',
#    'content': 'Using your device security instead of a password makes it harder to get tricked into giving up your Facebook account.\r\nFacebook is adding support for passkeys on its mobile app. That means youll be a… [+1552 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Emma Roth',
#    'title': 'House staffers can’t have WhatsApp on their devices',
#    'description': 'The House of Representatives has banned staff members from using WhatsApp on government devices, according to a report from Axios. In an email viewed by the outlet, the House’s chief administrative officer (CAO) tells staffers that the Office of Cybersecurity…',
#    'url': 'https://www.theverge.com/news/691288/house-of-representatives-whatsapp-ban-meta',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/STK110_whats_app_Kradtke_02.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-06-23T17:06:07Z',
#    'content': 'The chief administrative officer claims the messaging app is high-risk.\r\nThe House of Representatives has banned staff members from using WhatsApp on government devices, according to a report from Ax… [+1499 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Brad Smith',
#    'title': 'Netflix, Rivian, Microsoft: Trending Tickers',
#    'description': 'Netflix (NFLX) is reportedly expanding its efforts to make unscripted TV, with the streaming giant reportedly meeting with Spotify (SPOT) and The Daily Beast...',
#    'url': 'https://finance.yahoo.com/video/netflix-rivian-microsoft-trending-tickers-154849979.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/UeVbm2TnzH1cXG7QPHz4nQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzY-/https://s.yimg.com/os/creatr-uploaded-images/2025-07/6aa95c90-575b-11f0-bcff-bfe3b45c6a7f',
#    'publishedAt': '2025-07-02T15:48:49Z',
#    'content': "Now time for some of today's trending tickers. We are watching Netflix, Rivian, and yeah, Microsoft. First up, Netflix is upping its push into uns unscripted TV, reportedly exploring music shows and … [+1792 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Microsoft Sued By Authors Over Use of Books in AI Training',
#    'description': 'Microsoft has been hit with a lawsuit by a group of authors who claim the company used their books without permission to train its Megatron artificial intelligence model. From a report: Kai Bird, Jia Tolentino, Daniel Okrent and several others alleged that Mi…',
#    'url': 'https://news.slashdot.org/story/25/06/25/2137220/microsoft-sued-by-authors-over-use-of-books-in-ai-training',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/microsoft_64100.png',
#    'publishedAt': '2025-06-26T00:50:00Z',
#    'content': 'Kai Bird, Jia Tolentino, Daniel Okrent and several others alleged that Microsoft used pirated digital versions of their books to teach its AI to respond to human prompts. Their lawsuit, filed in New … [+449 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Lauren Feiner',
#    'title': 'Inside the courthouse reshaping the future of the internet',
#    'description': 'The future of the internet will be determined in one building in Washington, DC - and for six weeks, I watched it unfold. For much of this spring, the E. Barrett Prettyman Courthouse in downtown Washington, DC, was buzzing with lawyers, reporters, and interes…',
#    'url': 'https://www.theverge.com/policy/690440/e-barrett-prettyman-courthouse-dc-district-meta-google-antitrust-doge',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/257782_Courthouse_CVirginia.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-06-20T19:24:50Z',
#    'content': 'Inside the courthouse reshaping the future of the internet\r\nThe US District Court in Washington, DC, was the home of two of the most important tech trials in decades plus so much more.\r\nInside the co… [+8770 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Sean Hollister',
#    'title': 'Four reasons why it’s a surprisingly bad time to buy a gaming handheld',
#    'description': 'I love modern handheld gaming, and I recommend it to anyone and everyone. Just maybe not today? If you decided today was the day to finally drop hundreds of dollars on your first handheld, I might advise you to wait. Four reasons: The best handhelds are sold …',
#    'url': 'https://www.theverge.com/editorial/688415/state-of-handheld-gaming-editorial-switch-2-deck-oled-sold-out',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/247200_Asus_ROG_Ally_X_Review_LEDE_DSC02347_SHOLLISTER.webp?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-06-17T19:20:41Z',
#    'content': 'The Switch 2 and Steam Deck OLED are sold out and alternatives are suddenly looking a little less desirable.\r\nThe Switch 2 and Steam Deck OLED are sold out and alternatives are suddenly looking a lit… [+7456 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Stephen Fowler',
#    'title': 'Top House Democrat asks Microsoft about DOGE code allegedly tied to NLRB data removal',
#    'description': "A top House Democrat is asking Microsoft for information about a DOGE staffer's GitHub account connected to whistleblower allegations of sensitive data leaving the National Labor Relations Board.",
#    'url': 'https://www.npr.org/2025/06/16/nx-s1-5435330/congress-doge-nlrb-whistleblower-github',
#    'urlToImage': 'https://media.npr.org/assets/img/2025/04/15/doge_main_wide-7f9d19ebf39677aa2f91eaa2936905ee51c5b458.png?s=1400&c=100&f=png',
#    'publishedAt': '2025-06-16T15:54:18Z',
#    'content': 'The DOGE team may have taken data related to union organizing and labor complaints and hid its tracks, according to a whistleblower.\r\nCharlotte Gomez for NPR/NPR\r\nThe top Democrat on the House Oversi… [+3358 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Ashley Stewart',
#    'title': "Microsoft transfers a top cybersecurity executive out of the company's security group, internal memo shows",
#    'description': 'Igor Tsyganskiy is moving under Cloud + AI boss Scott Guthrie, another sign of how important artificial intelligence is becoming to Microsoft.',
#    'url': 'https://www.businessinsider.com/microsoft-moves-ciso-out-of-security-group-closer-ai-2025-6',
#    'urlToImage': 'https://i.insider.com/685c9855f748d8c055f46163?width=1200&format=jpeg',
#    'publishedAt': '2025-06-26T20:16:49Z',
#    'content': 'Igor TsyganskiyBridgewater Associates\r\n<ul><li>Microsoft moved its chief information security officer out of the security division.</li><li>Igor Tsyganskiy now reports to Cloud + AI boss Scott Guthri… [+3063 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Charles Rollet',
#    'title': 'Inside the high-stakes rift straining the most powerful alliance in tech',
#    'description': "Tensions are boiling between AI's biggest power couple. Discover the four key conflicts that might upend their $13 billion partnership.",
#    'url': 'https://www.businessinsider.com/openai-and-microsoft-are-clashing-over-money-power-and-agi-2025-6',
#    'urlToImage': 'https://i.insider.com/6862f19af748d8c055f4acb0?width=1200&format=jpeg',
#    'publishedAt': '2025-07-01T09:00:02Z',
#    'content': "OpenAI CEO Sam Altman (left) and Microsoft CEO Satya Nadellapicture alliance/Getty, YUICHI YAMAZAKI/Getty\r\n<ul><li>Microsoft is OpenAI's biggest investor but tensions between the two are boiling over… [+4793 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Ashley Stewart',
#    'title': 'Microsoft is working on a deal to add 1 million Copilot users from a single customer, exec says in internal meeting',
#    'description': 'Chief Commercial Officer Judson Althoff told employees in a recent meeting that the software giant is working on this big transaction.',
#    'url': 'https://www.businessinsider.com/microsoft-copilot-licenses-million-ai-2025-6',
# ...
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Sam-Altman-OpenAI-Snowflake-Summit-2025-1200x675.jpg',
#    'publishedAt': '2025-06-11T15:40:15Z',
#    'content': 'The AI brain rot in Silicon Valley manifests in many varieties. For OpenAIs figurehead Sam Altman, this often results in a lot of vague talk about artificial intelligence as the panacea to all of the… [+4849 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Alistair Barr',
#    'title': 'OpenAI and Microsoft are dueling over AGI. These real-world tests will prove when AI is really better than humans.',
#    'description': 'The most important AI partnership in the world partly revolves around whether OpenAI achieves AGI. I propose several practical tests.',
#    'url': 'https://www.businessinsider.com/openai-microsoft-duel-agi-real-world-tests-ai-better-humans-2025-6',
#    'urlToImage': 'https://i.insider.com/685efa313d5881a51c1c4b64?width=1200&format=jpeg',
#    'publishedAt': '2025-06-29T09:00:01Z',
#    'content': 'OpenAI CEO Sam Altman (left) and Microsoft CEO Satya NadellaJoel Saget/AFP and Loren Elliott via Getty Images\r\n<ul><li>A key part of the OpenAI and Microsoft partnership hinges on the startup achievi… [+6432 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Gizmodo Deals',
#    'title': 'Amazon Clears Out Dell Inspiron (Ryzen 7, 1TB SSD, Win 11 Pro) Stock, Now $2,800 Off and Bonuses Included',
#    'description': 'This is one of our top favorites at the moment.',
#    'url': 'https://gizmodo.com/amazon-clears-out-dell-inspiron-ryzen-7-1tb-ssd-win-11-pro-stock-now-2800-off-and-bonuses-included-2000616153',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/dell-inspiron-16-1200x675.jpg',
#    'publishedAt': '2025-06-16T11:40:22Z',
#    'content': 'Amazon currently has for sale a rare deal about a fantastic Windows laptop. There’s a Dell Inspiron 16-inch (touchscreen) laptop featuring an AMD Ryzen 7 processor, 32GB DDR5 RAM and a massive 1TB SS… [+2274 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Gizmodo Deals',
#    'title': 'Lenovo 15” 1TB Laptop with Windows 11 Pro for $399 (71% Off), Amazon Is Selling at No Profit',
#    'description': 'It feels great to pay just a third of the price for such a popular laptop.',
#    'url': 'https://gizmodo.com/lenovos-15-1tb-laptop-with-windows-11-pro-is-shockingly-cheap-71-off-no-prime-day-wait-needed-2000619430',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/lenovofhd-1200x675.jpg',
#    'publishedAt': '2025-06-24T13:25:57Z',
#    'content': 'Laptops are necessary for work, school and play, but it can be difficult to find one that’s both affordable and reliable – most good choices cost far less than $1000. One of the most reputable laptop… [+2005 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Brittany Vincent',
#    'title': 'Dell’s 15″ Touch Screen Laptop With 4.7-Star Rating Drops to All-Time Low Price, 40% Off Today Only',
#    'description': 'It can handle anything you throw at it and much, much more for a great price at Best Buy.',
#    'url': 'https://gizmodo.com/dells-15-touch-screen-laptop-with-4-7-star-rating-drops-to-all-time-low-price-40-off-today-only-2000612829',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/dinspiron-1200x675.jpg',
#    'publishedAt': '2025-06-09T12:40:34Z',
#    'content': 'If youve been weighing your options for a new laptop, now might be the perfect time to grab a reliable workhorse without going over budget. And believe it or not, it’s not that difficult to do. You c… [+2184 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Joe Tilleli',
#    'title': 'Dell’s Best-Selling Laptop (32GB RAM, 1TB SSD) With Windows 11 Pro Is Practically Free at 73% Off',
#    'description': 'Save $1,750 on the Dell 15 3530 Laptop with 1TB of storage and 32GB of memory.',
#    'url': 'https://gizmodo.com/dells-best-selling-laptop-32gb-ram-1tb-ssd-with-windows-11-pro-is-practically-free-at-73-2000617065',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Dell15-1200x675.jpg',
#    'publishedAt': '2025-06-21T12:35:50Z',
#    'content': 'Schools is out but the next semester will be here before you know it. Is you college student equipped to take on all their classes? Make sure they are kitted with the right laptop to get all their cl… [+1691 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Joe Tilleli',
#    'title': 'Dell’s Best-Selling Laptop (32GB RAM, 1TB SSD) With Windows 11 Pro Is Practically Free at 73% Off',
#    'description': 'Save $1,750 on the Dell 15 3530 Laptop with 1TB of storage and 32GB of memory.',
#    'url': 'https://gizmodo.com/dells-best-selling-laptop-32gb-ram-1tb-ssd-with-windows-11-pro-is-practically-free-at-73-off-2000617065',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Dell15-1200x675.jpg',
#    'publishedAt': '2025-06-18T12:40:50Z',
#    'content': 'Schools is out but the next semester will be here before you know it. Is you college student equipped to take on all their classes? Make sure they are kitted with the right laptop to get all their cl… [+2188 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': 'Pornhub Back Online in France After Court Ruling About Age Verification',
#    'description': 'The porn site calls age verification a security risk.',
#    'url': 'https://gizmodo.com/pornhub-back-online-in-france-after-court-ruling-about-age-verification-2000618221',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/12/PornHub.jpg',
#    'publishedAt': '2025-06-20T17:15:51Z',
#    'content': 'Many porn sites, including Pornhub, YouPorn, and RedTube, all went dark earlier this month in France to protest a new age verification law that would have required the websites to collect ID from use… [+2199 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'AJ Dellinger',
#    'title': 'Military Launches Website to Find Big Tech’s ‘Army Strong’ Employees',
#    'description': 'Silicon Valley heads to West Point.',
#    'url': 'https://gizmodo.com/military-launches-website-to-find-big-techs-army-strong-employees-2000620849',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/army-parade-1200x675.jpg',
#    'publishedAt': '2025-06-26T20:15:30Z',
#    'content': 'If you’re working in Big Tech and looking to make an exit, the Army is waiting with open arms. Someone’s gotta build the tech to drop these bombs, after all. Task and Purpose reports\xa0that the Army’s … [+2550 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': "Microsoft's New AI Tool Outperforms Doctors 4-to-1 in Diagnostic Accuracy",
#    'description': "Microsoft's new AI diagnostic system achieved 80% accuracy in diagnosing patients compared to 20% for human doctors, while reducing costs by 20%, according to company research published Monday. The MAI Diagnostic Orchestrator queries multiple leading AI model…",
#    'url': 'https://science.slashdot.org/story/25/06/30/1712220/microsofts-new-ai-tool-outperforms-doctors-4-to-1-in-diagnostic-accuracy',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/medicine_64.png?refresh=now',
#    'publishedAt': '2025-06-30T17:20:00Z',
#    'content': 'For one thing, doctors only 20% accurate? I know they make lots of mistakes, but that figure seems suspiciously low, and the article (and links) seem light on the specifics.\r\nAfter all, this is Micro… [+68 chars]'},
#   {'source': {'id': None, 'name': 'Harvard Business Review'},
#    'author': 'Trebor Scholz, Stefano Tortorici',
#    'title': '5 Ways Cooperatives Can Shape the Future of AI',
#    'description': 'Co-ops won’t outspend Big Tech, but they could offer a more viable, inclusive path for AI aligned with public interest.',
#    'url': 'https://hbr.org/2025/06/5-ways-cooperatives-can-shape-the-future-of-ai',
#    'urlToImage': 'https://hbr.org/resources/images/article_assets/2025/06/Jun25_25_2169900784.jpg',
#    'publishedAt': '2025-06-25T14:00:00Z',
#    'content': 'Today, AI development is controlled by a small cadre of firms. Companies like OpenAI, Alphabet, Amazon, Meta, and Microsoft dominate through vast computational resources, massive proprietary datasets… [+260 chars]'},
#   {'source': {'id': None, 'name': 'Digitrendz.blog'},
#    'author': 'The Wiz',
#    'title': 'Lyon Drops Microsoft to Boost Digital Sovereignty',
#    'description': '▼ Summary - Lyon will gradually replace Microsoft software with open-source alternatives like Only Office, Linux, and PostgreSQL to reduce dependency on U.S. solutions.- The city aims to achieve digit',
#    'url': 'https://digitrendz.blog/newswire/business/19813/lyon-drops-microsoft-office-to-boost-digital-sovereignty/',
#    'urlToImage': 'https://digitrendz.blog/wp-content/uploads/2025/06/Souverainete-1024x496-1.avif',
#    'publishedAt': '2025-06-25T09:05:12Z',
#    'content': '▼ Summary\r\n– Lyon will gradually replace Microsoftsoftware with open-source alternatives like Only Office, Linux, and PostgreSQL to reduce dependency on U.S. solutions.– The city aims to achieve digi… [+2075 chars]'},
#   {'source': {'id': None, 'name': 'Harvard Business Review'},
#    'author': 'Goran Calic, Andy Wu',
#    'title': 'Tech Companies, Nuclear Power, and the Problem of Strategic Timing',
#    'description': 'How to solve the dual problems of market readiness and supplier deadlines.',
#    'url': 'https://hbr.org/2025/06/tech-companies-nuclear-power-and-the-problem-of-strategic-timing',
#    'urlToImage': 'https://hbr.org/resources/images/article_assets/2025/05/Jun25_06_BarbaraGibson.jpg',
#    'publishedAt': '2025-06-11T12:05:42Z',
#    'content': 'In the last year, big tech companies went all-in on nuclear energy. Meta signed a 20-year deal with Constellation Energy Corp. for power from an Illinois reactor, Google signed a deal with Kairos Pow… [+258 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'Enterprise AI Adoption Stalls As Inferencing Costs Confound Cloud Customers',
#    'description': 'According to market analyst firm Canalys, enterprise adoption of AI is slowing due to unpredictable and often high costs associated with model inferencing in the cloud. Despite strong growth in cloud infrastructure spending, businesses are increasingly scruti…',
#    'url': 'https://news.slashdot.org/story/25/06/13/210224/enterprise-ai-adoption-stalls-as-inferencing-costs-confound-cloud-customers',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/ai_64.png',
#    'publishedAt': '2025-06-14T00:50:00Z',
#    'content': '[Canalys] published stats that show businesses spent $90.9 billion globally on infrastructure and platform-as-a-service with the likes of Microsoft, AWS and Google in calendar Q1, up 21 percent year-… [+1744 chars]'},
#   {'source': {'id': None, 'name': 'Kotaku'},
#    'author': 'Ethan Gach',
#    'title': "Everything We Saw At Xbox's Big Summer 2025 Showcase",
#    'description': 'Microsoft just concluded this year’s not-E3 festivities with a surprisingly great showcase that made up for all of the grim vibes and unfortunate shortcomings of Friday’s Summer Game Fest Live presentation. While the Xbox event wasn’t full of big first-party …',
#    'url': 'https://kotaku.com/everything-we-saw-at-xboxs-big-summer-2025-showcase-1851784007',
#    'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/89db8acf29b5113008accdbf18e643b3.png',
#    'publishedAt': '2025-06-08T19:55:16Z',
#    'content': 'Microsoft just concluded this years not-E3 festivities with a surprisingly great showcase that made up for all of the grim vibes and unfortunate shortcomings of Fridays Summer Game Fest Live presenta… [+883 chars]'},
#   {'source': {'id': None, 'name': 'VentureBeat'},
#    'author': 'Julius Černiauskas, Oxylabs',
#    'title': 'Cloud quantum computing: A trillion-dollar opportunity with dangerous hidden risks',
#    'description': 'Guest Join the event trusted by enterprise leaders for nearly two decades. VB Transform brings together the people building real enterprise AI strategy.\xa0Learn more Quantum computing (QC) brings with it a mix of groundbreaking possibilities and significant ris…',
#    'url': 'https://venturebeat.com/security/cloud-quantum-computing-a-trillion-dollar-opportunity-with-dangerous-hidden-risks/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2025/06/Quantum.webp?w=1024?w=1200&strip=all',
#    'publishedAt': '2025-06-21T20:00:00Z',
#    'content': 'Join the event trusted by enterprise leaders for nearly two decades. VB Transform brings together the people building real enterprise AI strategy.\xa0Learn more\r\nQuantum computing (QC) brings with it a … [+11602 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Joe Tilleli',
#    'title': 'Best Buy’s Giving You $1,000 Off Refurbished Microsoft Surface Touchscreen Laptop, Nearly Free Right Now',
#    'description': 'Save 75% on the refurbished 2017 Microsoft Surface laptop over at Best Buy.',
#    'url': 'https://gizmodo.com/best-buys-giving-you-1000-off-refurbished-microsoft-surface-touchscreen-laptop-nearly-free-right-now-2000615204',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/MicrosoftSurfaceRefurbished-1200x675.jpg',
#    'publishedAt': '2025-06-13T17:10:11Z',
#    'content': 'Looking to replace you laptop but dont feel like shelling out thousands for the latest MacBook? Well you dont need to sweat. You can grab yourself something perfectly capable of meeting your everyday… [+2191 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Joe Tilleli',
#    'title': 'Microsoft Surface Laptop 2 Is Going for Peanuts With Over 60% Off, a Limited Best Buy Certified Refurb Deal',
#    'description': 'Save $800 on the Microsoft Surface Laptop 2, certified refurbished by Geek Squad at Best Buy.',
#    'url': 'https://gizmodo.com/microsoft-surface-laptop-2-is-going-for-peanuts-with-over-60-off-a-limited-best-buy-certified-refurb-deal-2000616635',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/MicrosoftSurface-Refurbished-1200x675.jpg',
#    'publishedAt': '2025-06-17T15:10:39Z',
#    'content': 'Looking to replace you laptop but dont feel like shelling out thousands for the latest MacBook? Well you dont need to sweat. You can grab yourself something perfectly capable of meeting your everyday… [+2184 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Gizmodo Deals',
#    'title': 'If You Own an Xbox Series X/S, You Can Buy an Official 2TB Expansion Card for 40% Off on Amazon',
#    'description': 'This expansion card is a must-have if you own a next-generation Xbox.',
#    'url': 'https://gizmodo.com/if-you-own-an-xbox-series-x-s-you-can-buy-an-official-2tb-expansion-card-for-40-off-on-amazon-2000615437',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/03/Seagate-Xbox-Storage-Expansion-Card-2TB-1200x675.jpg',
#    'publishedAt': '2025-06-13T14:25:12Z',
#    'content': 'If you own an Xbox Series X or S, you’re already aware of how quickly your storage fills up with new games. Expansions are inevitable and the Seagate Expansion Card SSD is designed specifically for t… [+2527 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'AJ Dellinger',
#    'title': 'Salesforce CEO Claims Half of the Company’s Work Is Now Done by AI',
#    'description': "So if you've noticed a decline in quality, there's an explanation.",
#    'url': 'https://gizmodo.com/salesforce-ceo-claims-half-of-the-companys-work-is-now-done-by-ai-2000620730',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/11/Saleforce-CEO-Marc-Benioff-at-a-conference-in-San-Francisco-.jpg',
#    'publishedAt': '2025-06-26T17:30:46Z',
#    'content': 'While many companies that went all in on AI have since pulled back, Salesforce is going full steam ahead. In an interview with Bloomberg, CEO Marc Benioff claimed that as much as 30% to 50% of the co… [+2671 chars]'}]}

# %%
msft = pd.read_csv("msftdataHOURLY.csv")
msft.head()
# Out:
#                         Date       Close        High         Low        Open  \
# 0  2025-06-04 13:30:00+00:00  464.920105  465.640015  463.020111  464.000000
# 1  2025-06-04 14:30:00+00:00  464.631897  465.149994  463.769989  464.920013
# 2  2025-06-04 15:30:00+00:00  463.760010  465.089996  463.739990  464.660004
# 3  2025-06-04 16:30:00+00:00  464.700012  464.820007  463.665008  463.739990
# 4  2025-06-04 17:30:00+00:00  464.760010  465.100006  464.170013  464.690002
#
#     Volume
# 0  3207738
# 1  1513356
# 2   948127
# 3  1090878
# 4   767012

# %%
# Initialize FinBERT for sentiment analysis
def initialize_finbert():
    """Initialize FinBERT model for financial sentiment analysis"""
    model_name = "ProsusAI/finbert"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    
    # Create sentiment pipeline
    sentiment_pipeline = pipeline(
        "sentiment-analysis",
        model=model,
        tokenizer=tokenizer,
        return_all_scores=True
    )
    
    return sentiment_pipeline

def get_sentiment_score(text, sentiment_pipeline):
    """
    Get sentiment score from FinBERT (-1 to +1 scale)
    FinBERT outputs: positive, negative, neutral
    We'll convert to: positive=+1, negative=-1, neutral=0
    """
    try:
        # Truncate text to avoid token limit issues
        text = text[:512] if len(text) > 512 else text
        
        results = sentiment_pipeline(text)
        
        # FinBERT returns scores for all labels
        sentiment_scores = {result['label'].lower(): result['score'] for result in results[0]}
        
        # Convert to -1 to +1 scale
        if 'positive' in sentiment_scores and 'negative' in sentiment_scores:
            pos_score = sentiment_scores.get('positive', 0)
            neg_score = sentiment_scores.get('negative', 0)
            neutral_score = sentiment_scores.get('neutral', 0)
            
            # Weighted score: positive contributes +1, negative contributes -1
            weighted_score = (pos_score * 1) + (neg_score * -1) + (neutral_score * 0)
            return weighted_score
        else:
            return 0.0
            
    except Exception as e:
        print(f"Error processing sentiment: {e}")
        return 0.0

def process_news_data(newsdata):
    """
    Extract articles from newsdata dict and process them
    """
    articles = []
    
    if 'articles' in newsdata:
        for article in newsdata['articles']:
            # Extract relevant information
            article_data = {
                'title': article.get('title', ''),
                'description': article.get('description', ''),
                'content': article.get('content', ''),
                'publishedAt': article.get('publishedAt', ''),
                'source': article.get('source', {}).get('name', ''),
                'url': article.get('url', '')
            }
            
            # Combine title, description, and content for sentiment analysis
            full_text = f"{article_data['title']} {article_data['description']} {article_data['content']}"
            article_data['full_text'] = full_text.strip()
            
            # Convert publishedAt to datetime
            try:
                article_data['datetime'] = pd.to_datetime(article_data['publishedAt'])
            except:
                article_data['datetime'] = None
                
            articles.append(article_data)
    
    return pd.DataFrame(articles)

def create_hourly_sentiment_data(news_df, msft_datetimes, sentiment_pipeline):
    """
    Create hourly sentiment data aligned with MSFT datetime index
    """
    # Initialize sentiment data with zeros
    sentiment_data = pd.DataFrame({
        'datetime': msft_datetimes,
        'sentiment_score': 0.0
    })
    
    # Process each news article
    for idx, row in news_df.iterrows():
        if row['datetime'] is not None:
            # Get sentiment score
            sentiment_score = get_sentiment_score(row['full_text'], sentiment_pipeline)
            
            # Find the corresponding hour in MSFT data
            article_hour = row['datetime'].floor('H')
            
            # Find matching datetime in sentiment_data
            matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
            
            if not matching_rows.empty:
                # If multiple articles in same hour, average the sentiment
                current_sentiment = sentiment_data.loc[matching_rows.index[0], 'sentiment_score']
                if current_sentiment == 0:
                    sentiment_data.loc[matching_rows.index[0], 'sentiment_score'] = sentiment_score
                else:
                    # Average with existing sentiment
                    sentiment_data.loc[matching_rows.index[0], 'sentiment_score'] = (current_sentiment + sentiment_score) / 2
    
    return sentiment_data

def process_msft_data(msft_df):
    """
    Process MSFT dataframe to have proper datetime and only Close prices
    """
    # Create a copy to avoid modifying original
    msft_processed = msft_df.copy()
    
    # Reset index to make datetime a column if it's currently the index
    if msft_processed.index.name is not None or isinstance(msft_processed.index, pd.DatetimeIndex):
        msft_processed = msft_processed.reset_index()
    
    # Find datetime column (could be index or a column)
    datetime_col = None
    for col in msft_processed.columns:
        if 'datetime' in col.lower() or 'time' in col.lower() or 'date' in col.lower():
            datetime_col = col
            break
    
    if datetime_col is None and msft_processed.index.name:
        # Datetime might be in index
        msft_processed = msft_processed.reset_index()
        datetime_col = msft_processed.columns[0]
    
    # Convert datetime column to proper datetime
    if datetime_col:
        msft_processed['datetime'] = pd.to_datetime(msft_processed[datetime_col])
    else:
        # If no datetime column found, assume index is datetime
        msft_processed['datetime'] = pd.to_datetime(msft_processed.index)
    
    # Keep only datetime and Close columns
    if 'Close' in msft_processed.columns:
        msft_clean = msft_processed[['datetime', 'Close']].copy()
    elif 'PriceClose' in msft_processed.columns:
        msft_clean = msft_processed[['datetime', 'PriceClose']].copy()
        msft_clean.rename(columns={'PriceClose': 'Close'}, inplace=True)
    else:
        # Try to find close price column
        close_cols = [col for col in msft_processed.columns if 'close' in col.lower()]
        if close_cols:
            msft_clean = msft_processed[['datetime', close_cols[0]]].copy()
            msft_clean.rename(columns={close_cols[0]: 'Close'}, inplace=True)
        else:
            raise ValueError("Could not find Close price column in MSFT data")
    
    return msft_clean

def create_final_dataset(newsdata, msft_df):
    """
    Main function to create the final dataset with MSFT prices and sentiment scores
    """
    print("Step 1: Initializing FinBERT model...")
    sentiment_pipeline = initialize_finbert()
    
    print("Step 2: Processing news data...")
    news_df = process_news_data(newsdata)
    print(f"Found {len(news_df)} news articles")
    
    print("Step 3: Processing MSFT data...")
    msft_clean = process_msft_data(msft_df)
    print(f"MSFT data shape: {msft_clean.shape}")
    
    print("Step 4: Creating sentiment data aligned with MSFT timestamps...")
    sentiment_data = create_hourly_sentiment_data(news_df, msft_clean['datetime'], sentiment_pipeline)
    
    print("Step 5: Merging MSFT data with sentiment data...")
    final_df = pd.merge(msft_clean, sentiment_data, on='datetime', how='left')
    
    # Fill any missing sentiment scores with 0
    final_df['sentiment_score'] = final_df['sentiment_score'].fillna(0)
    
    print("Step 6: Final dataset created!")
    print(f"Final dataset shape: {final_df.shape}")
    print(f"Non-zero sentiment scores: {(final_df['sentiment_score'] != 0).sum()}")
    
    return final_df, msft_clean, sentiment_data

# %%
final_dataset, msft_processed, sentiment_df = create_final_dataset(newsdata, msft)
print(final_dataset.head(10))
print("\nDataset Info:")
print(final_dataset.info())
print("\nSentiment Score Statistics:")
print(final_dataset['sentiment_score'].describe())
# Out:
# Step 1: Initializing FinBERT model...
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# C:\Users\prast\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\prast\.cache\huggingface\hub\models--ProsusAI--finbert. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Device set to use cuda:0
# C:\Users\prast\AppData\Roaming\Python\Python311\site-packages\transformers\pipelines\text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Step 2: Processing news data...
# Found 100 news articles
# Step 3: Processing MSFT data...
# MSFT data shape: (143, 2)
# Step 4: Creating sentiment data aligned with MSFT timestamps...
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# Step 5: Merging MSFT data with sentiment data...
# Step 6: Final dataset created!
# Final dataset shape: (143, 3)
# Non-zero sentiment scores: 41
#                    datetime       Close  sentiment_score
# 0 2025-06-04 13:30:00+00:00  464.920105         0.000000
# 1 2025-06-04 14:30:00+00:00  464.631897         0.000000
# 2 2025-06-04 15:30:00+00:00  463.760010         0.865551
# 3 2025-06-04 16:30:00+00:00  464.700012         0.000000
# 4 2025-06-04 17:30:00+00:00  464.760010         0.000000
# 5 2025-06-04 18:30:00+00:00  464.359985         0.000000
# 6 2025-06-04 19:30:00+00:00  463.889008         0.000000
# 7 2025-06-05 13:30:00+00:00  466.404999         0.000000
# 8 2025-06-05 14:30:00+00:00  467.640015         0.000000
# 9 2025-06-05 15:30:00+00:00  468.184998         0.000000
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   datetime         143 non-null    datetime64[ns, UTC]
#  1   Close            143 non-null    float64
#  2   sentiment_score  143 non-null    float64
# dtypes: datetime64[ns, UTC](1), float64(2)
# memory usage: 3.5 KB
# None
#
# Sentiment Score Statistics:
# count    143.000000
# mean      -0.027588
# std        0.227423
# min       -0.916523
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.865551
# Name: sentiment_score, dtype: float64
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:98: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   article_hour = row['datetime'].floor('H')
# C:\Users\prast\AppData\Local\Temp\ipykernel_27688\2529106934.py:101: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   matching_rows = sentiment_data[sentiment_data['datetime'].dt.floor('H') == article_hour]

# %%
final_dataset.to_csv("final_dataset_with_sentiment.csv", index=False)
